# %%
from rich import print, inspect

# %%
from openai import OpenAI

client = OpenAI()

# %%
# initialize assistant 
assistant = client.beta.assistants.create(
    name="Math Tutor",
    instructions="You are a personal math tutor. Write and run code to answer math questions.",
    tools=[{"type": "code_interpreter"}],
    model="gpt-4-1106-preview"
)

# %%
# create a thread for the conversation
thread = client.beta.threads.create()

# %%
# add message
message = client.beta.threads.messages.create(
    thread_id=thread.id,
    role="user",
    content="I need to solve the equation `3x + 11 = 14`. Can you help me?"
)

# %%
# run assistant
#   to get model to respond -> create Run
#   this will decide what tool to use
run = client.beta.threads.runs.create(
    thread_id=thread.id,
    assistant_id=assistant.id,
    instructions="Please address the user as Tony. The user has a premium account."
)

# %%
# responses
run = client.beta.threads.runs.retrieve(
    thread_id=thread.id,
    run_id=run.id
)

messages = client.beta.threads.messages.list(thread_id=thread.id)

print(messages)
# Out:
# SyncCursorPage[ThreadMessage](
#     data=[
#         ThreadMessage(
#             id='msg_X8tV8xcA2XVF1EXOq3UTs0za',
#             assistant_id='asst_JJX5zjTaEbrxr4LytFBzul6Y',
#             content=[
#                 MessageContentText(
#                     text=Text(
#                         annotations=[],
#                         value='The solution to the equation \\(3x + 11 = 14\\) is \\(x = 1\\).'
#                     ),
#                     type='text'
#                 )
#             ],
#             created_at=1699312432,
#             file_ids=[],
#             metadata={},
#             object='thread.message',
#             role='assistant',
#             run_id='run_Wm8pamukC1sbMIo8mWtFcr6C',
#             thread_id='thread_DuumH1qnbtQfbCDZyB12gAYz'
#         ),
#         ThreadMessage(
#             id='msg_LrrxLg0TbBbK1Gz9RqVaWrWL',
#             assistant_id=None,
#             content=[
#                 MessageContentText(
#                     text=Text(
#                         annotations=[],
#                         value='I need to solve the equation `3x + 11 = 14`. Can you help me?'
#                     ),
#                     type='text'
#                 )
#             ],
#             created_at=1699312236,
#             file_ids=[],
#             metadata={},
#             object='thread.message',
#             role='user',
#             run_id=None,
#             thread_id='thread_DuumH1qnbtQfbCDZyB12gAYz'
#         )
#     ],
#     object='list',
#     first_id='msg_X8tV8xcA2XVF1EXOq3UTs0za',
#     last_id='msg_LrrxLg0TbBbK1Gz9RqVaWrWL',
#     has_more=False
# )

# %%
run_steps = client.beta.threads.runs.steps.list(
    thread_id=thread.id,
    run_id=run.id
)

print(run_steps)
# Out:
# SyncCursorPage[RunStep](
#     data=[
#         RunStep(
#             id='step_fGfUkpQ5byD30fJKOAvOwy8y',
#             assistant_id='asst_JJX5zjTaEbrxr4LytFBzul6Y',
#             cancelled_at=None,
#             completed_at=1699312432,
#             created_at=1699312432,
#             expired_at=None,
#             failed_at=None,
#             last_error=None,
#             metadata=None,
#             object='thread.run.step',
#             run_id='run_Wm8pamukC1sbMIo8mWtFcr6C',
#             status='completed',
#             step_details=MessageCreationStepDetails(
#                 message_creation=MessageCreation(message_id='msg_X8tV8xcA2XVF1EXOq3UTs0za'),
#                 type='message_creation'
#             ),
#             thread_id='thread_DuumH1qnbtQfbCDZyB12gAYz',
#             type='message_creation',
#             expires_at=None
#         ),
#         RunStep(
#             id='step_RykAiPh0R98hUyBdTnmImy6r',
#             assistant_id='asst_JJX5zjTaEbrxr4LytFBzul6Y',
#             cancelled_at=None,
#             completed_at=1699312432,
#             created_at=1699312428,
#             expired_at=None,
#             failed_at=None,
#             last_error=None,
#             metadata=None,
#             object='thread.run.step',
#             run_id='run_Wm8pamukC1sbMIo8mWtFcr6C',
#             status='completed',
#             step_details=ToolCallsStepDetails(
#                 tool_calls=[
#                     CodeToolCall(
#                         id='call_1C8edFhMmeh0SJ6UGlAyFhmQ',
#                         code_interpreter=CodeInterpreter(
#                             input="from sympy import symbols, Eq, solve\r\n\r\n# Define the symbol\r\nx =
# symbols('x')\r\n\r\n# Define the equation\r\nequation = Eq(3*x + 11, 14)\r\n\r\n# Solve the equation\r\nsolution =
# solve(equation, x)\r\nsolution",
#                             outputs=[CodeInterpreterOutputLogs(logs='[1]', type='logs')]
#                         ),
#                         type='code_interpreter'
#                     )
#                 ],
#                 type='tool_calls'
#             ),
#             thread_id='thread_DuumH1qnbtQfbCDZyB12gAYz',
#             type='tool_calls',
#             expires_at=None
#         )
#     ],
#     object='list',
#     first_id='step_fGfUkpQ5byD30fJKOAvOwy8y',
#     last_id='step_RykAiPh0R98hUyBdTnmImy6r',
#     has_more=False
# )
